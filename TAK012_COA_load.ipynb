# %% [markdown]
# # Code Owner : Igor Gonzalez
# ## Code Creation Date: 14th August 2023
# ## Code last edited on : 14st August 2023
# ### Code inputs: gamme_dalta table from RDS with all Gamma Delt batch records transcribed by Aventior
# ### Purpose
# #####  This notebook extracts final Gamma Delta product data from the CoA and and writes a new table on RDS
#
# ### code outputs:
# ####

# %%
import numpy as np
import pandas as pd
import sqlalchemy as db

# %%
#RDS strings 
#Redshift Strings
rds_user = 'corrsci_writer'
rds_password = 'atD4wgqXWNJbZ0CElweW'
rds_host = 'usvgactpdr001.cbeapk3hm22p.us-east-1.redshift.amazonaws.com'
rds_dialect = 'redshift+redshift_connector'
rds_port = '5439'
rds_database ='usvgactpdr001'
rds_string = f'{rds_dialect}://{rds_user}:{rds_password}@{rds_host}:{rds_port}/{rds_database}'
print(rds_string)
 
rds_engine= db.create_engine(rds_string)
rds_connection = rds_engine.connect()
# Out:
# redshift+redshift_connector://corrsci_writer:atD4wgqXWNJbZ0CElweW@usvgactpdr001.cbeapk3hm22p.us-east-1.redshift.amazonaws.com:5439/usvgactpdr001

# %%
table_name = 'gamme_delta'
gdx_table = pd.read_sql('SELECT x.* FROM corrsci.gamma_delta x', con = rds_connection)

# %%
gdx_table['description 1'].unique()
# Out:
# array(['', 'Certificate of Analysis for GDX012',
#        'Bill of Materials (BOM)', 'Equipment',
#        'Media and Cytokine Incubation',
#        'Manufacturing Receipt of Product',
#        'Frozen Recordings from HemaCare Certificate of Analysis',
#        'CliniMACS Buffer with 0.5% HSA Preparation', 'LOVO Set-Up',
#        'Thawing of Leukopaks and Sampling of Leukapheresis',
#        'Decision Tree', 'Leukapheresis Calculations',
#        'Cell Labeling with the LOVO', 'LOVO Antibody Reagent Preparation',
#        'Cell Labeling on the LOVO (continued)',
#        'LOVO Microbead Reagent Preparation',
#        'Labeled Leukapheresis Calculations', 'Preparation of CliniMACS',
#        'CliniMACS Sample Parameter', 'Post-CliniMACS Cells Sampling',
#        'Post-CliniMACS Sample', 'Buffer Exchange with LOVO',
#        'Post-LOVO 2 Cells Sample', 'Post Buffer Exchange Decision Tree',
#        'G-Rex Seeding Calculations',
#        'G-Rex 500M Cytokine Mix and Media Preparation',
# ...

# %%
gdx_table_coa = gdx_table[gdx_table['description 1'].isin(['Certificate of Analysis for GDX012'])]
gdx_table_coa
# Out:
#             file name form title page no. step no. day  \
# 6     GD03-21-001-CoA       FORM        1
# 7     GD03-21-001-CoA       FORM        1
# 8     GD03-21-001-CoA       FORM        1
# 9     GD03-21-001-CoA       FORM        1
# 10    GD03-21-001-CoA       FORM        1
# ...               ...        ...      ...      ...  ..
# 2868  GD03-21-003-CoA       FORM        1
# 2869  GD03-21-003-CoA       FORM        1
# 2870  GD03-21-003-CoA       FORM        1
# 2871  GD03-21-003-CoA       FORM        1
# 2872  GD03-21-003-CoA       FORM        1
#
#                            description 1  \
# 6     Certificate of Analysis for GDX012
# 7     Certificate of Analysis for GDX012
# 8     Certificate of Analysis for GDX012
# 9     Certificate of Analysis for GDX012
# 10    Certificate of Analysis for GDX012
# ...                                  ...
# 2868  Certificate of Analysis for GDX012
# 2869  Certificate of Analysis for GDX012
# 2870  Certificate of Analysis for GDX012
# ...

# %%
gdx_table_coa['description 2'].unique()
# Out:
# array(['Test to be_Performed_Appearance_Test Method_Visual Inspection',
#        'Test to be Performed_Quantity of viable cells per bag_Test Method_Dose Calculation',
#        'Test to be Performed_Viability_Test Method_Minaris RM WI-1390 Viability NC200',
#        'Test to be Performed_% Vδ1+ T-cells (of γδ+ T-cells)_Test Method_Minaris RM WI-1390 Flow Cytometry',
#        'Test to be Performed_% CD45+ cells (of total live cells)_Test Method_Minaris RM WI-1390 Flow Cytometry',
#        'Test to be Performed_% γδ+ T-cells (of CD45+ live cells)_Test Method_Minaris RM WI-1390 Flow Cytometry',
#        'Test to be Performed _% αβ+ T-cells (of CD45+ live cells)_Test Method_Minaris RM WI-1390 Flow Cytometry',
#        'Test to be Performed_Potency_Test Method_Minaris RM WI-1392 Interferon gamma ELISA',
#        'Test to be Performed_Sterility_Test Method_ BioReliance 510185 GMP.BSV Conforms to USP <71>',
# ...

# %%
replace_dict = {
       'Test to be_Performed_Appearance_Test Method_Visual Inspection': 'Appearance',
       'Test to be Performed_Quantity of viable cells per bag_Test Method_Dose Calculation': 'Visible Cells/bag',
       'Test to be Performed_Viability_Test Method_Minaris RM WI-1390 Viability NC200':'Viablility',
       'Test to be Performed_% Vδ1+ T-cells (of γδ+ T-cells)_Test Method_Minaris RM WI-1390 Flow Cytometry':'% Vδ1+ T-cells',
       'Test to be Performed_% CD45+ cells (of total live cells)_Test Method_Minaris RM WI-1390 Flow Cytometry': '% CD45+ cells',
       'Test to be Performed_% γδ+ T-cells (of CD45+ live cells)_Test Method_Minaris RM WI-1390 Flow Cytometry' : '% γδ+ T cells',
       'Test to be Performed _% αβ+ T-cells (of CD45+ live cells)_Test Method_Minaris RM WI-1390 Flow Cytometry' : '% αβ+ T-cells',
       'Test to be Performed_Potency_Test Method_Minaris RM WI-1392 Interferon gamma ELISA': 'Potency',
       'Test to be Performed_Sterility_Test Method_ BioReliance 510185 GMP.BSV Conforms to USP <71>': 'Sterility USP<71>',
       'Test to be Performed_Endotoxin_Test Method_ BioReliance 360195 GMP.BSV USP <85>': 'Endotoxin USP <85>',
       'Test to be Performed_Mycoplasma_Test Method_BioReliance 305214 GMP.BSV Conforms to USP <63>': 'Mycoplasma USP <63>',
       'Test to be Performed_Appearance_Test Method_Visual Inspection' : 'Appearance',
       'Test to be Performed_% Vδ1+ T-cells (of γδ+ T-cells)_Test Method_Minaris RM WI-1391 Flow Cytometry' :'% Vδ1+ T-cells',
       'Test to be Performed_% CD45+ cells (of total live cells)_Test Method_Minaris RM WI-1391 Flow Cytometry' : '% CD45+ cells',
       'Test to be Performed_% γδ+ T-cells (of CD45+ live cells)_Test Method_Minaris RM WI-1391 Flow Cytometry'  : '% γδ+ T cells',
       'Test to be Performed_% αβ+ T-cells (of CD45+ live cells)_Test Method_Minaris RM WI-1391 Flow Cytometry' : '% αβ+ T-cells',
       'Test to be Performed_Sterility_Test Method_BioReliance 510185 GMP.BSV Conforms to USP <71>': 'Sterility USP<71>',
       'Test to be Performed_Endotoxin_Test Method_BioReliance 360195 GMP.BSV USP <85>': 'Endotoxin USP <85>',
       'Test to be Performed_Mycoplasma_Test Method_BioReliance 305214 GMP.BSV Conforms USP <63>': 'Mycoplasma USP <63>'
}

# %%
gdx_table_coa.replace({'description 2':replace_dict},inplace=True)
gdx_table_coa
# Out:
# C:\Users\mvi2773\AppData\Local\Temp\1/ipykernel_16184/3849142912.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdx_table_coa.replace({'description 2':replace_dict},inplace=True)
#             file name form title page no. step no. day  \
# 6     GD03-21-001-CoA       FORM        1
# 7     GD03-21-001-CoA       FORM        1
# 8     GD03-21-001-CoA       FORM        1
# 9     GD03-21-001-CoA       FORM        1
# 10    GD03-21-001-CoA       FORM        1
# ...               ...        ...      ...      ...  ..
# 2868  GD03-21-003-CoA       FORM        1
# 2869  GD03-21-003-CoA       FORM        1
# 2870  GD03-21-003-CoA       FORM        1
# 2871  GD03-21-003-CoA       FORM        1
# 2872  GD03-21-003-CoA       FORM        1
#
# ...

# %%
gdx_table_coa['description 3'].unique()
# Out:
# array(['Acceptance Criteria', 'Pass/Fail', 'Results'], dtype=object)

# %%
gdx_table_coa.replace({'description 3':{'Acceptance Criteria':'Spec'}},inplace=True)
gdx_table_coa
# Out:
# C:\Users\mvi2773\AppData\Local\Temp\1/ipykernel_16184/3363067206.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdx_table_coa.replace({'description 3':{'Acceptance Criteria':'Spec'}},inplace=True)
#             file name form title page no. step no. day  \
# 6     GD03-21-001-CoA       FORM        1
# 7     GD03-21-001-CoA       FORM        1
# 8     GD03-21-001-CoA       FORM        1
# 9     GD03-21-001-CoA       FORM        1
# 10    GD03-21-001-CoA       FORM        1
# ...               ...        ...      ...      ...  ..
# 2868  GD03-21-003-CoA       FORM        1
# 2869  GD03-21-003-CoA       FORM        1
# 2870  GD03-21-003-CoA       FORM        1
# 2871  GD03-21-003-CoA       FORM        1
# ...

# %%
gdx_table_coa['column to pivot'] = gdx_table_coa['description 2'] + '_' +  gdx_table_coa['description 3']
# Out:
# C:\Users\mvi2773\AppData\Local\Temp\1/ipykernel_16184/3748742192.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdx_table_coa['column to pivot'] = gdx_table_coa['description 2'] + '_' +  gdx_table_coa['description 3']

# %%
for  parameter in gdx_table_coa['description 2'].unique():
    print(parameter)
# Out:
# Appearance
# Visible Cells/bag
# Viablility
# % Vδ1+ T-cells
# % CD45+ cells
# % γδ+ T cells
# % αβ+ T-cells
# Potency
# Sterility USP<71>
# Endotoxin USP <85>
# Mycoplasma USP <63>

# %%
coa_pivot = pd.pivot(gdx_table_coa,index='file name', columns = 'column to pivot', values = 'result')
coa_pivot
# Out:
# column to pivot % CD45+ cells_Pass/Fail % CD45+ cells_Results  \
# file name
# GD03-21-001-CoA                    Pass                   100
# GD03-21-002-CoA                    Pass                   100
# GD03-21-003-CoA                    Pass                   100
#
# column to pivot % CD45+ cells_Spec % Vδ1+ T-cells_Pass/Fail  \
# file name
# GD03-21-001-CoA             90-100                     Pass
# GD03-21-002-CoA             90-100                     Pass
# GD03-21-003-CoA             90-100                     Pass
#
# column to pivot % Vδ1+ T-cells_Results % Vδ1+ T-cells_Spec  \
# file name
# GD03-21-001-CoA                     75              51-100
# GD03-21-002-CoA                     77              51-100
# GD03-21-003-CoA                     75              51-100
#
# column to pivot % αβ+ T-cells_Pass/Fail % αβ+ T-cells_Results  \
# file name
# GD03-21-001-CoA                    Pass                  0.06
# ...

# %%
# Out:
# column to pivot % CD45+ cells_Pass/Fail % CD45+ cells_Results  \
# file name
# GD03-21-001-CoA                    Pass                   100
# GD03-21-002-CoA                    Pass                   100
# GD03-21-003-CoA                    Pass                   100
#
# column to pivot % CD45+ cells_Spec % Vδ1+ T-cells_Pass/Fail  \
# file name
# GD03-21-001-CoA             90-100                     Pass
# GD03-21-002-CoA             90-100                     Pass
# GD03-21-003-CoA             90-100                     Pass
#
# column to pivot % Vδ1+ T-cells_Results % Vδ1+ T-cells_Spec  \
# file name
# GD03-21-001-CoA                     75              51-100
# GD03-21-002-CoA                     77              51-100
# GD03-21-003-CoA                     75              51-100
#
# column to pivot % αβ+ T-cells_Pass/Fail % αβ+ T-cells_Results  \
# file name
# GD03-21-001-CoA                    Pass                  0.06
# ...

# %%
for column in coa_pivot.columns.tolist():
    coa_pivot[column] = pd.to_numeric(coa_pivot[column],errors = 'ignore')
coa_pivot.select_dtypes(include= np.number).columns.tolist()
# Out:
# ['% CD45+ cells_Results',
#  '% Vδ1+ T-cells_Results',
#  '% αβ+ T-cells_Results',
#  '% γδ+ T cells_Results',
#  'Potency_Results',
#  'Viablility_Results',
#  'Visible Cells/bag_Results',
#  'Visible Cells/bag_Spec']

# %%
#RDS strings 
rds_user = 'cellthera'
rds_password = 'Rh2OL!05Zxt24'
rds_host = 'usvgarps92565-dev002.cdhvwd3rr6fj.us-east-1.rds.amazonaws.com'
rds_dialect = 'postgresql'
rds_port = '5442'
rds_database ='postgres'
rds_string = f'{rds_dialect}://{rds_user}:{rds_password}@{rds_host}:{rds_port}/{rds_database}'
print(rds_string)
 
rds_engine= db.create_engine(rds_string)
rds_connection = rds_engine.connect()
# Out:
# postgresql://cellthera:Rh2OL!05Zxt24@usvgarps92565-dev002.cdhvwd3rr6fj.us-east-1.rds.amazonaws.com:5442/postgres

# %%
for column in coa_pivot.columns.tolist():
    print(column, len(column))
#print(tak940_table_ready.columns)
coa_pivot.to_sql('gamma_delta_coa',rds_engine,schema='public')
# Out:
# % CD45+ cells_Pass/Fail 23
# % CD45+ cells_Results 21
# % CD45+ cells_Spec 18
# % Vδ1+ T-cells_Pass/Fail 24
# % Vδ1+ T-cells_Results 22
# % Vδ1+ T-cells_Spec 19
# % αβ+ T-cells_Pass/Fail 23
# % αβ+ T-cells_Results 21
# % αβ+ T-cells_Spec 18
# % γδ+ T cells_Pass/Fail 23
# % γδ+ T cells_Results 21
# % γδ+ T cells_Spec 18
# Appearance_Pass/Fail 20
# Appearance_Results 18
# Appearance_Spec 15
# Endotoxin USP <85>_Pass/Fail 28
# Endotoxin USP <85>_Results 26
# Endotoxin USP <85>_Spec 23
# Mycoplasma USP <63>_Pass/Fail 29
# Mycoplasma USP <63>_Results 27
# Mycoplasma USP <63>_Spec 24
# Potency_Pass/Fail 17
# Potency_Results 15
# Potency_Spec 12
# Sterility USP<71>_Pass/Fail 27
# Sterility USP<71>_Results 25
# Sterility USP<71>_Spec 22
# Viablility_Pass/Fail 20
# Viablility_Results 18
# Viablility_Spec 15
# Visible Cells/bag_Pass/Fail 27
# Visible Cells/bag_Results 25
# Visible Cells/bag_Spec 22
# 3
